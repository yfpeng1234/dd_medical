# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
lr=1
sigma=1
data=pd.read_csv('./data/score_{}_{}.csv'.format(lr,sigma))
data=data.to_numpy().squeeze()
x=np.arange(1,len(data)+1)
plt.plot(x,data)

# %%
import numpy as np
1/np.sqrt(np.pi)
# Out:
# 0.5641895835477563
